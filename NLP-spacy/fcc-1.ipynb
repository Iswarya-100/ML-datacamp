# %% [markdown]
# #### Free Code Camp - Natural Language Processing

# %%
! pip install -U pip setuptools wheel
# Out:
# ...
#   Using cached setuptools-84.0.0-py3-none-any.whl.metadata (6.6 kB)
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----------- ---------------------------- 0.5/1.8 MB 800.0 kB/s eta 0:00:02
#    ----------------- ---------------------- 0.8/1.8 MB 810.6 kB/s eta 0:00:02
#    ----------------- ---------------------- 0.8/1.8 MB 810.6 kB/s eta 0:00:02
#    ----------------------- ---------------- 1.0/1.8 MB 849.3 kB/s eta 0:00:01
#    ---------------------------- ----------- 1.3/1.8 MB 851.0 kB/s eta 0:00:01
#    ---------------------------------- ----- 1.6/1.8 MB 865.8 kB/s eta 0:00:01
#    ---------------------------------- ----- 1.6/1.8 MB 865.8 kB/s eta 0:00:01
# ...

# %%
! pip install -U spacy
# Out:
# ...
#    ---------------------------------------- 0.0/15.2 MB ? eta -:--:--
#     --------------------------------------- 0.3/15.2 MB ? eta -:--:--
#    - -------------------------------------- 0.5/15.2 MB 1.3 MB/s eta 0:00:12
#    -- ------------------------------------- 0.8/15.2 MB 1.5 MB/s eta 0:00:10
#    --- ------------------------------------ 1.3/15.2 MB 1.7 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.6/15.2 MB 1.6 MB/s eta 0:00:09
#    ---- ----------------------------------- 1.8/15.2 MB 1.6 MB/s eta 0:00:09
#    ----- ---------------------------------- 2.1/15.2 MB 1.5 MB/s eta 0:00:09
#    ------ --------------------------------- 2.4/15.2 MB 1.5 MB/s eta 0:00:09
#    ------ --------------------------------- 2.6/15.2 MB 1.4 MB/s eta 0:00:09
#    ------- -------------------------------- 2.9/15.2 MB 1.4 MB/s eta 0:00:09
#    -------- ------------------------------- 3.1/15.2 MB 1.4 MB/s eta 0:00:09
# ...

# %%
! python -m spacy download en_core_web_sm
# Out:
# ...
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#       --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#       --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#       --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#      - ------------------------------------- 0.5/12.8 MB 511.4 kB/s eta 0:00:25
#      - ------------------------------------- 0.5/12.8 MB 511.4 kB/s eta 0:00:25
#      - ------------------------------------- 0.5/12.8 MB 511.4 kB/s eta 0:00:25
#      -- ------------------------------------ 0.8/12.8 MB 444.0 kB/s eta 0:00:28
#      -- ------------------------------------ 0.8/12.8 MB 444.0 kB/s eta 0:00:28
# ...

# %%
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
with open("datasets/wiki_us.txt", "r") as file:
    text = file.read()

# %%
print(text)
# Out:
# The United States of America (U.S.A. or USA), commonly known as the United States (U.S. or US) or America, is a country primarily located in North America. It consists of 50 states, a federal district, five major unincorporated territories, 326 Indian reservations, and some minor possessions.[j] At 3.8 million square miles (9.8 million square kilometers), it is the world's third- or fourth-largest country by total area.[d] The United States shares significant land borders with Canada to the north and Mexico to the south, as well as limited maritime borders with the Bahamas, Cuba, and Russia.[22] With a population of more than 331 million people, it is the third most populous country in the world. The national capital is Washington, D.C., and the most populous city is New York.
#
# ...

# %%
doc = nlp(text)

# %%
doc
# Out:
# The United States of America (U.S.A. or USA), commonly known as the United States (U.S. or US) or America, is a country primarily located in North America. It consists of 50 states, a federal district, five major unincorporated territories, 326 Indian reservations, and some minor possessions.[j] At 3.8 million square miles (9.8 million square kilometers), it is the world's third- or fourth-largest country by total area.[d] The United States shares significant land borders with Canada to the north and Mexico to the south, as well as limited maritime borders with the Bahamas, Cuba, and Russia.[22] With a population of more than 331 million people, it is the third most populous country in the world. The national capital is Washington, D.C., and the most populous city is New York.
#
# ...

# %%
print(len(text))
print(len(doc))
# Out:
# 3525
# 652

# %%
for token in text[:10]:
    print(token)
# Out:
# T
# h
# e
#
# U
# n
# i
# t
# e
# d

# %%
for token in doc[:10]:
    print(token)
# Out:
# The
# United
# States
# of
# America
# (
# U.S.A.
# or
# USA
# )

# %%
for token in text.split()[:10]:
    print(token)
# Out:
# The
# United
# States
# of
# America
# (U.S.A.
# or
# USA),
# commonly
# known

# %%
text.split(".")[:10]
# Out:
# ['The United States of America (U',
#  'S',
#  'A',
#  ' or USA), commonly known as the United States (U',
#  'S',
#  ' or US) or America, is a country primarily located in North America',
#  ' It consists of 50 states, a federal district, five major unincorporated territories, 326 Indian reservations, and some minor possessions',
#  '[j] At 3',
#  '8 million square miles (9',
#  "8 million square kilometers), it is the world's third- or fourth-largest country by total area"]

# %%
for sent in doc.sents:
    print(sent)
    print("****")
# Out:
# The United States of America (U.S.A. or USA), commonly known as the United States (U.S. or US) or America, is a country primarily located in North America.
# ****
# It consists of 50 states, a federal district, five major unincorporated territories, 326 Indian reservations, and some minor possessions.[j]
# ****
# At 3.8 million square miles (9.8 million square kilometers), it is the world's third- or fourth-largest country by total area.[d]
# ****
# The United States shares significant land borders with Canada to the north and Mexico to the south, as well as limited maritime borders with the Bahamas, Cuba, and Russia.[22] With a population of more than 331 million people, it is the third most populous country in the world.
# ****
# The national capital is Washington, D.C., and the most populous city is New York.
#
#
# ****
# Paleo-Indians migrated from Siberia to the North American mainland at least 12,000 years ago, and European colonization began in the 16th century.
# ****
# ...

# %%
sentence = doc.sents[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 sentence = doc.sents[0]
#
# TypeError: '_cython_3_3_0.generator' object is not subscriptable

# %%
sentence1 = list(doc.sents)[0]

# %%
sentence1
# Out:
# The United States of America (U.S.A. or USA), commonly known as the United States (U.S. or US) or America, is a country primarily located in North America.

# %% [markdown]
# ##### Linguistic Annotations

# %%
token2 = sentence1[2]
print(token2)
# Out:
# States

# %%
token2.text
# Out:
# 'States'

# %%
token2.left_edge
# Out:
# The

# %%
token2.right_edge
# Out:
# ,

# %%
token2.ent_type, token2.ent_type_
# Out:
# (384, 'GPE')

# %%
# b - beginning of the entity
# i - inside of the entity
# o - outside of the entity

token2.ent_iob, token2.ent_iob_
# Out:
# (1, 'I')

# %%
token2.lemma_ # root
# Out:
# 'States'

# %%
token2.morph
# Out:
# Number=Sing

# %%
sentence1[12].morph # Perfect Past Participle :)
# Out:
# Aspect=Perf|Tense=Past|VerbForm=Part

# %%
token2.pos_
# Out:
# 'PROPN'

# %%
token2.dep_
# Out:
# 'nsubj'

# %%
token2.lang_
# Out:
# 'en'

# %%
text2 = "Mike enjoys playing Football."
doc2 = nlp(text2)
print(doc2)
# Out:
# Mike enjoys playing Football.

# %%
for token in doc2:
    print(token.text, token.pos_, token.dep_)
# Out:
# Mike PROPN nsubj
# enjoys VERB ROOT
# playing VERB xcomp
# Football PROPN dobj
# . PUNCT punct

# %%
from spacy import displacy

displacy.render(doc2, style="dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="e50ca540a4aa4880be602bd302260941-0" class="displacy" width="750" height="224.5" direction="ltr" style="max-width: none; height: 224.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Mike</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">enjoys</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
# ...
